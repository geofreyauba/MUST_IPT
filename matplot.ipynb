# %%
import pandas as pd
import numpy as np

# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
plt .plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([2,4,5,6,3,5])

# %%
x=[1,2,3,4,5,6]
y=[12,24,36,48,60,72]
plt.plot(x,y);

# %%
fig, ax =plt.subplots()
ax.plot(x,[23,45,65,68,56,99]);

# %%
fig, ax=plt.subplots()
ax.plot(x,y);

# %%
fig ,ax=plt.subplots()
ax.plot(x,y);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig,ax =plt.subplots(figsize=(10,1))
ax.plot(x,y)

ax.set(title="This is it and am going to run it now",
        xlabel="x baby",
        ylabel="y baby"
)
fig.savefig("sample.png")

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**3);

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.cos(x))

# %%
fig, ax =plt.subplots()
ax.bar(x,x)
# Out:
# <BarContainer object of 100 artists>

# %%
x= np.random.randn(1000)
fig ,ax=plt.subplots()
ax.hist(x);
